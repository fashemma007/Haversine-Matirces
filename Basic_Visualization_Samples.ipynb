# %% [markdown]
# #### Import relevant Libraires

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 972kB 9.4MB/s
# ...
#      |████████████████████████████████| 14.8MB 290kB/s
# ...
#      |████████████████████████████████| 6.5MB 34.3MB/s
# ...

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import io
from google.colab import files
from shapely.geometry import Point, LineString
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# #### Import Data

# %%
stop=files.upload()
# Out:
#      <input type="file" id="files-c0e8f63f-fb9f-4410-b0f1-d3a9abdf912f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0e8f63f-fb9f-4410-b0f1-d3a9abdf912f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Lag POIs.csv to Lag POIs.csv

# %%
POIs=pd.read_csv(io.BytesIO(stop['Lag POIs.csv']))

# %% [markdown]
# #### Display Data

# %%
POIs
# Out:
#                                                Name  ...         Sunday
# 0                            0 degree lounge & club  ...     9pm–5:30am
# 1                                 01 Shawarma Ikeja  ...    10am–8:20pm
# 2                01MANDARIN CHINESE TAKEAWAY MAGODO  ...       10am–9pm
# 3                               11:30 Events Center  ...            NaN
# 4                                        114 Houses  ...            NaN
# ...                                             ...  ...            ...
# 2879  Ziggies Entertainment Centre Ikosi Ketu Lagos  ...            NaN
# 2880        Ziggies Events Center Ikosi Ketu 100248  ...            NaN
# 2881                    Zion Hall & Events Dibor St  ...            NaN
# 2882                      ZOE MEDICAL CENTRE 100001  ...  Open 24 hours
# 2883                      Zone Tech Park Beside UPS  ...         Closed
#
# [2884 rows x 29 columns]

# %% [markdown]
# #### Display Column Headers

# %%
POIs.columns
# Out:
# Index(['Name', 'Category', 'Full_Address', 'Street_Address', 'City', 'State',
#        'Website', 'Phone', 'Email', 'Facebook', 'Twitter', 'Instagram', 'Lat',
#        'Lng', 'Category.1', 'Top_Image_URL', 'Sub_Title', 'Pricing',
#        'Amenities', 'Description', 'Summary', 'Monday', 'Tuesday', 'Wednesday',
#        'Thursday', 'Friday', 'Saturday', 'Category.2', 'Sunday'],
#       dtype='object')

# %% [markdown]
# #### Picking the Needed Columns and assigning them to separate dataframes

# %%
POI_1=POIs[['Name','Lat','Lng','Category','State']]


POI_2=POIs[['Name','Category','Monday', 'Tuesday', 'Wednesday','Thursday', 'Friday', 'Saturday']]

# %% [markdown]
# #### Getting Unique Count of the Place Category

# %%
POI_1['Category'].value_counts()
# Out:
# Event Centres             421
# Hotels/Guest Houses       393
# Banks                     321
# Shopping Malls            266
# Night Club                249
# Government Offices (S)    229
# Restuarants               162
# Hospitals                 161
# Unsorted                  120
# Beaches                   117
# Cinema                     85
# Embassies                  77
# Churches                   54
# Tourism                    54
# Hotel                      52
# Government Offices (F)     42
# Court                      33
# Market                     27
# Recreation Centres          7
# Stadium                     6
# Transportation              2
# Schools                     2
# University                  2
# NYSC                        1
# Workshops                   1
# Name: Category, dtype: int64

# %% [markdown]
# #### Dropping all rows with missing Values in both dataframes

# %%
POI_1=POI_1.dropna(axis=0)

POI_2=POI_2.dropna(axis=0)

# %% [markdown]
# #### Display Data

# %%
POI_1
# Out:
#                                                Name       Lat       Lng        Category       State
# 0                            0 degree lounge & club  6.494342  3.357373      Night Club       Lagos
# 1                                 01 Shawarma Ikeja  6.612556  3.345403     Restuarants       Ikeja
# 2                01MANDARIN CHINESE TAKEAWAY MAGODO  6.614273  3.371890     Restuarants       Lagos
# 3                               11:30 Events Center  6.596253  3.501233   Event Centres     Ikorodu
# 4                                        114 Houses  6.456433  3.397745  Shopping Malls       Lagos
# ...                                             ...       ...       ...             ...         ...
# 2879  Ziggies Entertainment Centre Ikosi Ketu Lagos  6.622731  3.372688       Unsorted        Lagos
# 2880        Ziggies Events Center Ikosi Ketu 100248  6.619067  3.367213   Event Centres           s
# ...

# %% [markdown]
# #### Convert POI_1 to Dataframe

# %%
P1=pd.DataFrame(POI_1)
P1
# Out:
#                                                Name  ...       State
# 0                            0 degree lounge & club  ...       Lagos
# 1                                 01 Shawarma Ikeja  ...       Ikeja
# 2                01MANDARIN CHINESE TAKEAWAY MAGODO  ...       Lagos
# 3                               11:30 Events Center  ...     Ikorodu
# 4                                        114 Houses  ...       Lagos
# ...                                             ...  ...         ...
# 2879  Ziggies Entertainment Centre Ikosi Ketu Lagos  ...       Lagos
# 2880        Ziggies Events Center Ikosi Ketu 100248  ...           s
# 2881                    Zion Hall & Events Dibor St  ...           s
# 2882                      ZOE MEDICAL CENTRE 100001  ...           s
# 2883                      Zone Tech Park Beside UPS  ...  Expressway
#
# [2867 rows x 5 columns]

# %% [markdown]
# #### Converting P1 to a list and picking a sample coordinate

# %%
stop_da=P1[['Name','Lat','Lng']].values.tolist()

stops=P1[['Lat','Lng']].values.tolist()

stop_da
stops [5]
# Out:
# [6.5062083, 3.3675812999999994]

# %% [markdown]
# #### Plotting the sample to center the basemap

# %%
map=folium.Map([6.5062083, 3.3675812999999994],tiles='openstreetmap',zoom_start=11)

map

# %% [markdown]
# #### Plotting our Data on the basemap and adding attrbutes as pop-up

# %%
for points in range(0,len(stops)):
    folium.Marker(stops[point],popup=POI_1['Name'][point]).add_to(map)

#map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d3e2785c27f8> in <module>()
#       1 for points in range(0,len(stops)):
# ----> 2     folium.Marker(stop[point],popup=POI_1['Name'][point]).add_to(map)
#       3
#       4 #map
#
# NameError: name 'point' is not defined

# %% [markdown]
# #### Visualizing the clusters of the place points

# %%
m = folium.Map(location=[6.5062083, 3.3675812999999994], zoom_start=10)

#marker_cluster = MarkerCluster().add_to(m)
#for point in range(0, len(stops)):
 #   folium.Marker(stops[point],popup=POIs['Name'][point]).add_to(marker_cluster)
    
    
#locations = list(zip(accident_data.Latitude, accident_data.Longitude))
icons = [folium.Icon(icon="car", prefix="fa") for _ in range(len(stops))]

cluster = MarkerCluster(locations=stops, icons=icons)
m.add_child(cluster) #popup=POIs['Name'][point]).add_to(marker_cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
